# %%
# import dependecies
import pandas as pd
import matplotlib.pyplot as plt
import requests
import numpy as np
from config import weather_key
from scipy.stats import linregress
from citipy import citipy
import json

# %%
# save config information
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'imperial'

# building partial query url
query_url = f'{url}appid={weather_key}&units={units}&q='

# %%
# range of latitude and longitude
lat = (-90,90)
lng = (-180,180)

# define count to pass through
count = 0
set_counter = 0

# %%
# list to hold cities and coordinates
cities = []
latutides_longitudes = []


# using uniform distribution, create a set of random latitudes and longitudes
latitudes = np.random.uniform(low=-90.0000, high=90.0000, size=1500)
longitudes = np.random.uniform(low=-180.0000, high=180.0000, size=1500)
latitudes_longitudes = zip(latitudes, longitudes)

# identify nearest city for each coordinates combination
for lat_lng in latitudes_longitudes:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    if city not in cities: # only add to list if the city found is unique
        cities.append(city)
        
#print(cities)
#len(cities)

# get a glimpse of the json print for df variable creation
response = requests.get(query_url+city).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 94
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 55.1153,
#         "lon": 83.9059
#     },
#     "dt": 1655555395,
#     "id": 1506254,
#     "main": {
#         "feels_like": 60.87,
#         "grnd_level": 975,
#         "humidity": 88,
#         "pressure": 1003,
#         "sea_level": 1003,
#         "temp": 60.94,
#         "temp_max": 60.94,
#         "temp_min": 60.94
#     },
#     "name": "Gornyy",
#     "rain": {
#         "1h": 0.28
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1655502228,
#         "sunset": 1655564825
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 253,
#         "gust": 13.58,
#         "speed": 8.66
#     }
# }

# %% [markdown]
# #  API calls

# %%
# set empty lists of variables for df creation 
info = 0
citi = []
latitudes = []
longitudes = []
cloudiness = []
humidity = []
temperatures = []
windspeed = []
country = []
city_name = []
date = []


print('Beginning data retrieval\n----------------------------')
# loop through url info to generate dataframe columns
for city in cities:
    
    # create search query
    response = requests.get(query_url + city).json()
    try:
        latitudes.append(response['coord']['lat'])
        longitudes.append(response['coord']['lon'])
        cloudiness.append(response['clouds']['all'])
        humidity.append(response['main']['humidity'])
        temperatures.append(response['main']['temp'])
        windspeed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
    
        if count < 50: 
            count = 1
            set_counter += 1
            citi.append(city)
        else:
            count = 1
            set_counter += 1
        print(f'Processing record {count} for set {set_counter} | {city}')
    except Exception:
        print(f'City not found. Skipping...')
print('----------\nData retrieval complete:)\n-----------')
# Out:
# Beginning data retrieval
# ----------------------------
# Processing record 1 for set 1 | barrow
# Processing record 1 for set 2 | cape town
# Processing record 1 for set 3 | liaoyang
# Processing record 1 for set 4 | riyadh
# City not found. Skipping...
# Processing record 1 for set 5 | ushuaia
# Processing record 1 for set 6 | kenai
# Processing record 1 for set 7 | lompoc
# Processing record 1 for set 8 | maniitsoq
# Processing record 1 for set 9 | rikitea
# Processing record 1 for set 10 | omsukchan
# Processing record 1 for set 11 | hobart
# Processing record 1 for set 12 | ilulissat
# Processing record 1 for set 13 | iquitos
# Processing record 1 for set 14 | touros
# Processing record 1 for set 15 | vaini
# Processing record 1 for set 16 | porbandar
# Processing record 1 for set 17 | busselton
# Processing record 1 for set 18 | tasiilaq
# Processing record 1 for set 19 | clyde river
# Processing record 1 for set 20 | tecpan
# Processing record 1 for set 21 | storsteinnes
# Processing record 1 for set 22 | kruisfontein
# Processing record 1 for set 23 | kannur
# Processing record 1 for set 24 | college
# Processing record 1 for set 25 | arlit
# Processing record 1 for set 26 | torri di quartesolo
# Processing record 1 for set 27 | kaitangata
# City not found. Skipping...
# Processing record 1 for set 28 | finschhafen
# Processing record 1 for set 29 | chokurdakh
# Processing record 1 for set 30 | mangan
# Processing record 1 for set 31 | hilo
# Processing record 1 for set 32 | cidreira
# Processing record 1 for set 33 | severo-kurilsk
# City not found. Skipping...
# Processing record 1 for set 34 | albany
# Processing record 1 for set 35 | arinos
# Processing record 1 for set 36 | hermanus
# Processing record 1 for set 37 | kang
# Processing record 1 for set 38 | kavieng
# Processing record 1 for set 39 | west wendover
# Processing record 1 for set 40 | manggar
# Processing record 1 for set 41 | changji
# Processing record 1 for set 42 | lata
# Processing record 1 for set 43 | panzhihua
# Processing record 1 for set 44 | mataura
# Processing record 1 for set 45 | souillac
# City not found. Skipping...
# City not found. Skipping...
# Processing record 1 for set 46 | butaritari
# Processing record 1 for set 47 | tay ninh
# Processing record 1 for set 48 | olafsvik
# Processing record 1 for set 49 | iroquois falls
# Processing record 1 for set 50 | mar del plata
# Processing record 1 for set 51 | planaltina
# Processing record 1 for set 52 | caxito
# Processing record 1 for set 53 | san patricio
# Processing record 1 for set 54 | evensk
# Processing record 1 for set 55 | avarua
# Processing record 1 for set 56 | saint-augustin
# Processing record 1 for set 57 | saurimo
# Processing record 1 for set 58 | tuktoyaktuk
# Processing record 1 for set 59 | kapaa
# Processing record 1 for set 60 | geraldton
# Processing record 1 for set 61 | lebu
# Processing record 1 for set 62 | pemangkat
# Processing record 1 for set 63 | constitucion
# Processing record 1 for set 64 | atuona
# Processing record 1 for set 65 | jamestown
# City not found. Skipping...
# Processing record 1 for set 66 | ongandjera
# Processing record 1 for set 67 | freeport
# Processing record 1 for set 68 | tiksi
# Processing record 1 for set 69 | sangar
# Processing record 1 for set 70 | omboue
# City not found. Skipping...
# Processing record 1 for set 71 | henties bay
# Processing record 1 for set 72 | punta arenas
# Processing record 1 for set 73 | puerto ayora
# Processing record 1 for set 74 | toyooka
# Processing record 1 for set 75 | oga
# City not found. Skipping...
# Processing record 1 for set 76 | codrington
# Processing record 1 for set 77 | fortuna
# Processing record 1 for set 78 | ponta do sol
# Processing record 1 for set 79 | east london
# Processing record 1 for set 80 | itoman
# Processing record 1 for set 81 | atambua
# Processing record 1 for set 82 | torbay
# Processing record 1 for set 83 | camocim
# Processing record 1 for set 84 | havre-saint-pierre
# Processing record 1 for set 85 | atar
# Processing record 1 for set 86 | adrar
# Processing record 1 for set 87 | ulladulla
# City not found. Skipping...
# Processing record 1 for set 88 | new norfolk
# Processing record 1 for set 89 | byron bay
# Processing record 1 for set 90 | khatanga
# Processing record 1 for set 91 | dunedin
# Processing record 1 for set 92 | hasaki
# Processing record 1 for set 93 | lucapa
# Processing record 1 for set 94 | preobrazheniye
# Processing record 1 for set 95 | namibe
# Processing record 1 for set 96 | yellowknife
# Processing record 1 for set 97 | provideniya
# City not found. Skipping...
# Processing record 1 for set 98 | salumbar
# Processing record 1 for set 99 | bambous virieux
# Processing record 1 for set 100 | chuy
# Processing record 1 for set 101 | north platte
# Processing record 1 for set 102 | luoyang
# Processing record 1 for set 103 | dikson
# Processing record 1 for set 104 | posse
# Processing record 1 for set 105 | carnarvon
# Processing record 1 for set 106 | yibin
# Processing record 1 for set 107 | kodiak
# Processing record 1 for set 108 | port keats
# Processing record 1 for set 109 | bandarbeyla
# Processing record 1 for set 110 | nikolskoye
# Processing record 1 for set 111 | hirara
# Processing record 1 for set 112 | castro
# Processing record 1 for set 113 | airai
# Processing record 1 for set 114 | bumba
# City not found. Skipping...
# Processing record 1 for set 115 | yarkovo
# Processing record 1 for set 116 | cap malheureux
# Processing record 1 for set 117 | faanui
# Processing record 1 for set 118 | kwekwe
# Processing record 1 for set 119 | port elizabeth
# Processing record 1 for set 120 | andapa
# Processing record 1 for set 121 | upernavik
# Processing record 1 for set 122 | laguna
# Processing record 1 for set 123 | saskylakh
# Processing record 1 for set 124 | buraydah
# Processing record 1 for set 125 | dudinka
# Processing record 1 for set 126 | chapais
# Processing record 1 for set 127 | nyagan
# Processing record 1 for set 128 | salalah
# Processing record 1 for set 129 | karasjok
# Processing record 1 for set 130 | nardaran
# Processing record 1 for set 131 | broken hill
# Processing record 1 for set 132 | jalu
# Processing record 1 for set 133 | acapulco
# Processing record 1 for set 134 | bengkulu
# Processing record 1 for set 135 | arraial do cabo
# City not found. Skipping...
# City not found. Skipping...
# Processing record 1 for set 136 | saint-pierre
# Processing record 1 for set 137 | ucluelet
# Processing record 1 for set 138 | dingle
# Processing record 1 for set 139 | wajid
# Processing record 1 for set 140 | coquimbo
# Processing record 1 for set 141 | hohhot
# City not found. Skipping...
# City not found. Skipping...
# Processing record 1 for set 142 | jimenez
# Processing record 1 for set 143 | tecoanapa
# Processing record 1 for set 144 | necochea
# City not found. Skipping...
# Processing record 1 for set 145 | kavaratti
# Processing record 1 for set 146 | atbasar
# Processing record 1 for set 147 | grindavik
# City not found. Skipping...
# Processing record 1 for set 148 | vao
# Processing record 1 for set 149 | coria
# Processing record 1 for set 150 | bredasdorp
# Processing record 1 for set 151 | leningradskiy
# Processing record 1 for set 152 | port alfred
# Processing record 1 for set 153 | victoria
# Processing record 1 for set 154 | alekseyevskoye
# Processing record 1 for set 155 | irbeyskoye
# Processing record 1 for set 156 | lorengau
# Processing record 1 for set 157 | sisimiut
# Processing record 1 for set 158 | margate
# Processing record 1 for set 159 | srednekolymsk
# Processing record 1 for set 160 | marrakesh
# Processing record 1 for set 161 | pita
# Processing record 1 for set 162 | salgado de sao felix
# Processing record 1 for set 163 | vernon
# Processing record 1 for set 164 | sorland
# Processing record 1 for set 165 | khed brahma
# Processing record 1 for set 166 | sadat
# Processing record 1 for set 167 | port lincoln
# Processing record 1 for set 168 | lagoa
# Processing record 1 for set 169 | wasilla
# Processing record 1 for set 170 | khromtau
# Processing record 1 for set 171 | ribeira grande
# Processing record 1 for set 172 | port-cartier
# Processing record 1 for set 173 | vestmannaeyjar
# Processing record 1 for set 174 | la libertad
# Processing record 1 for set 175 | gimli
# Processing record 1 for set 176 | honolulu
# Processing record 1 for set 177 | saint-philippe
# Processing record 1 for set 178 | flin flon
# Processing record 1 for set 179 | umm bab
# Processing record 1 for set 180 | qaanaaq
# Processing record 1 for set 181 | fare
# Processing record 1 for set 182 | bethel
# Processing record 1 for set 183 | linqiong
# City not found. Skipping...
# Processing record 1 for set 184 | luderitz
# Processing record 1 for set 185 | vardo
# Processing record 1 for set 186 | soc trang
# Processing record 1 for set 187 | santa rosa
# Processing record 1 for set 188 | lerwick
# Processing record 1 for set 189 | mehamn
# Processing record 1 for set 190 | solnechnyy
# Processing record 1 for set 191 | guerrero negro
# Processing record 1 for set 192 | mahebourg
# Processing record 1 for set 193 | port hardy
# Processing record 1 for set 194 | northam
# Processing record 1 for set 195 | winnemucca
# Processing record 1 for set 196 | hithadhoo
# Processing record 1 for set 197 | esperance
# Processing record 1 for set 198 | thompson
# Processing record 1 for set 199 | iwanai
# Processing record 1 for set 200 | almaznyy
# Processing record 1 for set 201 | fujin
# Processing record 1 for set 202 | alofi
# Processing record 1 for set 203 | bluff
# Processing record 1 for set 204 | jaisalmer
# City not found. Skipping...
# Processing record 1 for set 205 | marquette
# Processing record 1 for set 206 | tigre
# Processing record 1 for set 207 | marathon
# Processing record 1 for set 208 | ghanzi
# Processing record 1 for set 209 | nioro
# Processing record 1 for set 210 | biskamzha
# City not found. Skipping...
# Processing record 1 for set 211 | flinders
# Processing record 1 for set 212 | oussouye
# Processing record 1 for set 213 | camabatela
# Processing record 1 for set 214 | banda aceh
# Processing record 1 for set 215 | georgetown
# Processing record 1 for set 216 | ocampo
# Processing record 1 for set 217 | meulaboh
# Processing record 1 for set 218 | mount gambier
# Processing record 1 for set 219 | boyolangu
# Processing record 1 for set 220 | bongaree
# Processing record 1 for set 221 | spring valley
# City not found. Skipping...
# Processing record 1 for set 222 | san andres
# Processing record 1 for set 223 | priiskovyy
# Processing record 1 for set 224 | bejar
# Processing record 1 for set 225 | richards bay
# Processing record 1 for set 226 | mercedes
# Processing record 1 for set 227 | luwuk
# Processing record 1 for set 228 | bichena
# Processing record 1 for set 229 | mpulungu
# Processing record 1 for set 230 | ngunguru
# Processing record 1 for set 231 | cururupu
# Processing record 1 for set 232 | pasni
# Processing record 1 for set 233 | phuket
# Processing record 1 for set 234 | kaeo
# City not found. Skipping...
# Processing record 1 for set 235 | taquarituba
# Processing record 1 for set 236 | berlevag
# Processing record 1 for set 237 | nalut
# Processing record 1 for set 238 | bathsheba
# Processing record 1 for set 239 | san cristobal
# Processing record 1 for set 240 | kousseri
# Processing record 1 for set 241 | norman wells
# Processing record 1 for set 242 | santa isabel
# City not found. Skipping...
# Processing record 1 for set 243 | pimenteiras
# Processing record 1 for set 244 | hegra
# Processing record 1 for set 245 | calais
# Processing record 1 for set 246 | berberati
# Processing record 1 for set 247 | gizo
# Processing record 1 for set 248 | george town
# Processing record 1 for set 249 | bowen
# Processing record 1 for set 250 | port-gentil
# Processing record 1 for set 251 | havelock
# Processing record 1 for set 252 | neuquen
# Processing record 1 for set 253 | black river
# Processing record 1 for set 254 | winneba
# Processing record 1 for set 255 | cao bang
# Processing record 1 for set 256 | mitsamiouli
# Processing record 1 for set 257 | asfi
# Processing record 1 for set 258 | hualmay
# Processing record 1 for set 259 | vila velha
# Processing record 1 for set 260 | dawson creek
# Processing record 1 for set 261 | terney
# Processing record 1 for set 262 | puerto penasco
# Processing record 1 for set 263 | kupang
# Processing record 1 for set 264 | damietta
# City not found. Skipping...
# Processing record 1 for set 265 | ranot
# Processing record 1 for set 266 | fort nelson
# Processing record 1 for set 267 | namatanai
# Processing record 1 for set 268 | shimoda
# Processing record 1 for set 269 | klang
# Processing record 1 for set 270 | noshiro
# Processing record 1 for set 271 | kahului
# Processing record 1 for set 272 | bay roberts
# Processing record 1 for set 273 | anadyr
# Processing record 1 for set 274 | palmeira das missoes
# Processing record 1 for set 275 | sokolo
# Processing record 1 for set 276 | manono
# Processing record 1 for set 277 | hermosillo
# Processing record 1 for set 278 | tete
# Processing record 1 for set 279 | ponta delgada
# Processing record 1 for set 280 | sept-iles
# Processing record 1 for set 281 | iqaluit
# Processing record 1 for set 282 | santiago
# Processing record 1 for set 283 | saldanha
# Processing record 1 for set 284 | neuruppin
# Processing record 1 for set 285 | arman
# Processing record 1 for set 286 | korla
# Processing record 1 for set 287 | katsuura
# Processing record 1 for set 288 | riachao das neves
# City not found. Skipping...
# Processing record 1 for set 289 | beringovskiy
# Processing record 1 for set 290 | zarubino
# Processing record 1 for set 291 | kokopo
# Processing record 1 for set 292 | vila franca do campo
# Processing record 1 for set 293 | dharmavaram
# Processing record 1 for set 294 | tuskegee
# Processing record 1 for set 295 | saint george
# Processing record 1 for set 296 | narsaq
# Processing record 1 for set 297 | deputatskiy
# Processing record 1 for set 298 | panaba
# Processing record 1 for set 299 | huarmey
# Processing record 1 for set 300 | escanaba
# City not found. Skipping...
# Processing record 1 for set 301 | alta floresta
# Processing record 1 for set 302 | galle
# Processing record 1 for set 303 | vestmanna
# Processing record 1 for set 304 | ouadda
# Processing record 1 for set 305 | hofn
# Processing record 1 for set 306 | tukrah
# Processing record 1 for set 307 | santa cruz cabralia
# Processing record 1 for set 308 | rocha

# %% [markdown]
# ## Dataframe creation and cleaning

# %%
# create dictionary 
info_df = pd.DataFrame({
    'City': citi,
    'Country':country,
    'Latitude':latitudes,
    'Longitude':longitudes,
    'Humidity':humidity,
    'Windspeed':windspeed,
    'Cloudiness':cloudiness,
    'Temperatures':temperatures,
    'Date':date
})
info_df.head()

# save the csv
#info_df.to_csv('weather_df', encoding='utf-8',index=False)
# Out:
#            City Country  Latitude  Longitude  Humidity  Windspeed  Cloudiness  \
# 0        dwarka      IN   22.2394    68.9678        70      16.73          46
# 1       mataura      NZ  -46.1927   168.8643        96       2.91         100
# 2  saint george      US   37.1041  -113.5841        22       5.75           0
# 3         uyuni      BO  -20.4597   -66.8250        18       5.46           0
# 4  punta arenas      CL  -53.1500   -70.9167        74      11.50          40
#
#    Temperatures        Date
# 0         88.77  1655544378
# 1         42.48  1655544378
# 2         74.50  1655544379
# 3         26.47  1655544379
# 4         30.31  1655544379

# %%
# get summary statistics
info_df.describe()
# Out:
#          Latitude   Longitude    Humidity   Windspeed  Cloudiness  \
# count  530.000000  530.000000  530.000000  530.000000  530.000000
# mean    20.816889   12.071868   68.960377    8.439755   58.252830
# std     32.938845   91.911282   22.854193    5.581656   38.805222
# min    -54.800000 -179.166700    1.000000    0.000000    0.000000
# 25%     -4.885925  -68.877450   55.000000    4.340000   20.000000
# 50%     25.403250   15.538300   74.000000    7.605000   72.000000
# 75%     49.170775   90.139650   87.000000   11.500000   99.000000
# max     78.218600  179.316700  100.000000   30.530000  100.000000
#
#        Temperatures          Date
# count    530.000000  5.300000e+02
# mean      67.935358  1.655544e+09
# std       15.877450  6.097006e+01
# min       26.470000  1.655544e+09
# 25%       55.470000  1.655544e+09
# 50%       71.125000  1.655544e+09
# 75%       79.502500  1.655544e+09
# max      106.250000  1.655545e+09

# %%
# remove cities with humidity >100
# info_df['Humidity'].value_counts()
humidity_check = info_df.sort_values('Humidity', ascending=False)
print('No values >100 in humidity, thus plot!')
humidity_check.head()
# Out:
# No values >100 in humidity, thus plot!
#                 City Country  Latitude  Longitude  Humidity  Windspeed  \
# 501      fort nelson      CA   58.8053  -122.7002       100       3.44
# 139  arraial do cabo      BR  -22.9661   -42.0278       100       3.44
# 387          terrace      CA   54.5163  -128.6035       100       3.44
# 405    puerto madero      MX   14.7208   -92.4215       100       5.75
# 242         matagami      CA   49.7502   -77.6328       100      18.41
#
#      Cloudiness  Temperatures        Date
# 501         100         45.99  1655544521
# 139          20         60.66  1655544425
# 387         100         55.31  1655544493
# 405         100         75.40  1655544498
# 242         100         35.71  1655544453

# %%
info_df.dtypes
# Out:
# City             object
# Country          object
# Latitude        float64
# Longitude       float64
# Humidity          int64
# Windspeed       float64
# Cloudiness        int64
# Temperatures    float64
# Date              int64
# dtype: object

# %% [markdown]
# ## Plotting scatterplots

# %%
# create temp vs lat scatter
y1= info_df['Temperatures']
x1= info_df['Latitude']
plt.scatter(x1,y1, marker='o',edgecolors='red')
plt.grid()
plt.xlabel('latitude')
plt.ylabel('temperature (F)')
plt.title('Latitude vs Temp(F)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# create humidity vs lat scatter
x2= info_df['Latitude']
y2= info_df['Humidity']
plt.scatter(x2,y2, marker='x')
plt.grid()
plt.xlabel('latitude')
plt.ylabel('humidity (%)')
plt.title('Latitude vs Humidity(%)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# create cloudiness vs lat scatter
x3= info_df['Latitude']
y3= info_df['Cloudiness']
plt.scatter(x3,y3, marker='*')
plt.grid()
plt.xlabel('latitude')
plt.ylabel('cloudiness')
plt.title('Latitude vs Cloudiness')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# create humidity vs lat scatter
x4= info_df['Latitude']
y4= info_df['Windspeed']
plt.scatter(x4,y4, marker='x')
plt.grid()
plt.xlabel('latitude')
plt.ylabel('windspeed (mph)')
plt.title('Latitude vs Windspeed(mph)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ### Northern Hemisphere

# %%
# using original dataframe create a northern hemisphere dataframe 
# in this case latitude will be > 0
# equator = 0
northern_hem_df = info_df[info_df['Latitude']>0]
northern_hem_df.head()
# save csv
northern_hem_df.to_csv('northern hemisphere df', encoding='utf-8', index=False)

# %%
# linregress temp vs lat on scatter
yn1= northern_hem_df['Temperatures']
xn1= northern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xn1, yn1)
regress_values = xn1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xn1,yn1, marker='^')
plt.plot(xn1,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=10,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('temperature (F)')
plt.title('Latitude vs Temp(F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5050885124158166

# %%
# linregress humidity vs lat on scatter
yn2= northern_hem_df['Humidity']
xn2= northern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xn2, yn2)
regress_values = xn1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xn2,yn2, marker='x')
plt.plot(xn2,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=12,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('Humidity (%)')
plt.title('Latitude vs Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00545956164137885

# %%
# linregress cloudiness vs lat on scatter
yn3= northern_hem_df['Cloudiness']
xn3= northern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xn3, yn3)
regress_values = xn3 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xn3,yn3, marker='*')
plt.plot(xn3,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=12,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('Cloudiness(%)')
plt.title('Latitude vs Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00289637377901993

# %%
# linregress windspeed vs lat on scatter
yn4= northern_hem_df['Windspeed']
xn4= northern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xn4, yn4)
regress_values = xn4 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xn4,yn4, marker='o')
plt.plot(xn4,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=12,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('Windspeed (mph)')
plt.title('Latitude vs Windspeed(mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.005134555812935204

# %% [markdown]
# ### Southern Hemisphere

# %%
# using original dataframe create a southern hemisphere dataframe 
# in this case latitude will be < 0
# equator = 0
southern_hem_df = info_df[info_df['Latitude']<0]
southern_hem_df.head()
southern_hem_df.to_csv('southern hemisphere df', encoding='utf-8', index=False)

# %%
# linregress temp vs lat on scatter
ys1= southern_hem_df['Temperatures']
xs1= southern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xs1, ys1)
regress_values = xs1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xs1,ys1, marker='o')
plt.plot(xs1,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('temperature (F)')
plt.title('Latitude vs Temp(F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5665041726884782

# %%
# linregress temp vs lat on scatter
ys2= southern_hem_df['Humidity']
xs2= southern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xs2, ys2)
regress_values = xs2 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xs2,ys2, marker='o')
plt.plot(xs2,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('Humidity (%)')
plt.title('Latitude vs Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.012254866274020362

# %%
# linregress temp vs lat on scatter
ys3= southern_hem_df['Cloudiness']
xs3= southern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xs3, ys3)
regress_values = xs3 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xs3,ys3, marker='o')
plt.plot(xs3,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Latitude vs Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.009294087533571792

# %%
# linregress windspeed vs lat on scatter
ys4= southern_hem_df['Windspeed']
xs4= southern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xs4, ys4)
regress_values = xs4 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xs4,ys4, marker='o')
plt.plot(xs4,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('Windspeed (mph)')
plt.title('Latitude vs Windspeed(mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.05522897109445439
