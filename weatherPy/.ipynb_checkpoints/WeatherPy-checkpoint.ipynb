# %%
# import dependecies
import pandas as pd
import matplotlib.pyplot as plt
import requests
import numpy as np
from config import weather_key
from scipy.stats import linregress
from citipy import citipy
import json

# %%
# save config information
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'imperial'

# building partial query url
query_url = f'{url}appid={weather_key}&units={units}&q='

# %%
# range of latitude and longitude
lat = (-90,90)
lng = (-180,180)

# define count to pass through
count = 0
set_counter = 0

# %%
# list to hold cities and coordinates
cities = []
latutides_longitudes = []


# using uniform distribution, create a set of random latitudes and longitudes
latitudes = np.random.uniform(low=-90.0000, high=90.0000, size=1500)
longitudes = np.random.uniform(low=-180.0000, high=180.0000, size=1500)
latitudes_longitudes = zip(latitudes, longitudes)

# identify nearest city for each coordinates combination
for lat_lng in latitudes_longitudes:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    if city not in cities: # only add to list if the city found is unique
        cities.append(city)
        
#print(cities)
#len(cities)

# get a glimpse of the json print for df variable creation
response = requests.get(query_url+city).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.6001,
#         "lon": -73.9662
#     },
#     "dt": 1655169559,
#     "id": 5106841,
#     "main": {
#         "feels_like": 64.36,
#         "humidity": 63,
#         "pressure": 1015,
#         "temp": 65.19,
#         "temp_max": 68.65,
#         "temp_min": 62.29
#     },
#     "name": "Albany",
#     "sys": {
#         "country": "US",
#         "id": 2037353,
#         "sunrise": 1655111862,
#         "sunset": 1655166859,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 286,
#         "gust": 20.45,
#         "speed": 7
#     }
# }

# %% [markdown]
# #  API calls

# %%
# set empty lists of variables for df creation 
info = 0
citi = []
latitudes = []
longitudes = []
cloudiness = []
humidity = []
temperatures = []
windspeed = []
country = []
city_name = []
date = []


print('Beginning data retrieval\n----------------------------')
# loop through url info to generate dataframe columns
for city in cities:
    
    # create search query
    response = requests.get(query_url + city).json()
    try:
        latitudes.append(response['coord']['lat'])
        longitudes.append(response['coord']['lon'])
        cloudiness.append(response['clouds']['all'])
        humidity.append(response['main']['humidity'])
        temperatures.append(response['main']['temp'])
        windspeed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
    
        if count < 50: 
            count = 1
            set_counter += 1
            citi.append(city)
        else:
            count = 1
            set_counter += 1
        print(f'Processing record {count} for set {set_counter} | {city}')
    except Exception:
        print(f'City not found. Skipping...')
print('----------\nData retrieval complete:)\n-----------')
# Out:
# Beginning data retrieval
# ----------------------------
# Processing record 1 for set 552 | kamenka
# Processing record 1 for set 553 | busselton
# Processing record 1 for set 554 | kruisfontein
# Processing record 1 for set 555 | port alfred
# Processing record 1 for set 556 | vila franca do campo
# Processing record 1 for set 557 | georgetown
# Processing record 1 for set 558 | saldanha
# Processing record 1 for set 559 | mahebourg
# Processing record 1 for set 560 | guaratinga
# Processing record 1 for set 561 | mataura
# Processing record 1 for set 562 | carnarvon
# Processing record 1 for set 563 | martil
# Processing record 1 for set 564 | high rock
# Processing record 1 for set 565 | kavieng
# Processing record 1 for set 566 | norsup
# Processing record 1 for set 567 | tyulgan
# Processing record 1 for set 568 | atuona
# Processing record 1 for set 569 | ushuaia
# Processing record 1 for set 570 | chokurdakh
# Processing record 1 for set 571 | kapaa
# Processing record 1 for set 572 | jamestown
# Processing record 1 for set 573 | bengkulu
# Processing record 1 for set 574 | verkhnetulomskiy
# Processing record 1 for set 575 | la ronge
# Processing record 1 for set 576 | puerto escondido
# Processing record 1 for set 577 | seymchan
# City not found. Skipping...
# City not found. Skipping...
# Processing record 1 for set 578 | cape town
# Processing record 1 for set 579 | monrovia
# Processing record 1 for set 580 | pilar
# Processing record 1 for set 581 | albany
# Processing record 1 for set 582 | camacha
# Processing record 1 for set 583 | piacabucu
# Processing record 1 for set 584 | paamiut
# Processing record 1 for set 585 | torbay
# Processing record 1 for set 586 | tasiilaq
# Processing record 1 for set 587 | new norfolk
# Processing record 1 for set 588 | san cristobal
# Processing record 1 for set 589 | caravelas
# Processing record 1 for set 590 | inverell
# City not found. Skipping...
# Processing record 1 for set 591 | cap malheureux
# Processing record 1 for set 592 | shache
# Processing record 1 for set 593 | saint-philippe
# Processing record 1 for set 594 | daoukro
# Processing record 1 for set 595 | rikitea
# Processing record 1 for set 596 | nikolskoye
# Processing record 1 for set 597 | yar-sale
# Processing record 1 for set 598 | khatanga
# Processing record 1 for set 599 | olutanga
# Processing record 1 for set 600 | lenger
# Processing record 1 for set 601 | manakara
# Processing record 1 for set 602 | lima
# Processing record 1 for set 603 | punta arenas
# Processing record 1 for set 604 | bluff
# Processing record 1 for set 605 | bairiki
# Processing record 1 for set 606 | moissala
# City not found. Skipping...
# Processing record 1 for set 607 | marawi
# Processing record 1 for set 608 | ancud
# Processing record 1 for set 609 | chuy
# Processing record 1 for set 610 | hilo
# Processing record 1 for set 611 | provideniya
# Processing record 1 for set 612 | lensk
# Processing record 1 for set 613 | klaksvik
# Processing record 1 for set 614 | daultala
# Processing record 1 for set 615 | cidreira
# Processing record 1 for set 616 | moose factory
# Processing record 1 for set 617 | sandwick
# Processing record 1 for set 618 | khandbari
# Processing record 1 for set 619 | alofi
# Processing record 1 for set 620 | touros
# Processing record 1 for set 621 | dong hoi
# Processing record 1 for set 622 | akyab
# Processing record 1 for set 623 | avarua
# Processing record 1 for set 624 | evans
# City not found. Skipping...
# Processing record 1 for set 625 | kudahuvadhoo
# Processing record 1 for set 626 | kodiak
# Processing record 1 for set 627 | vaini
# Processing record 1 for set 628 | vostok
# Processing record 1 for set 629 | te anau
# Processing record 1 for set 630 | pevek
# Processing record 1 for set 631 | kavaratti
# Processing record 1 for set 632 | puerto ayora
# Processing record 1 for set 633 | coquimbo
# Processing record 1 for set 634 | taoudenni
# Processing record 1 for set 635 | butaritari
# Processing record 1 for set 636 | longyearbyen
# Processing record 1 for set 637 | kahului
# Processing record 1 for set 638 | khuzhir
# Processing record 1 for set 639 | houma
# Processing record 1 for set 640 | barrow
# Processing record 1 for set 641 | bethel
# City not found. Skipping...
# Processing record 1 for set 642 | vaitape
# Processing record 1 for set 643 | dingle
# Processing record 1 for set 644 | hermanus
# Processing record 1 for set 645 | salalah
# Processing record 1 for set 646 | isangel
# Processing record 1 for set 647 | zhigalovo
# Processing record 1 for set 648 | erzin
# Processing record 1 for set 649 | makhinjauri
# Processing record 1 for set 650 | hobart
# Processing record 1 for set 651 | yumen
# Processing record 1 for set 652 | singaraja
# City not found. Skipping...
# Processing record 1 for set 653 | el playon
# Processing record 1 for set 654 | scarborough
# Processing record 1 for set 655 | port elizabeth
# Processing record 1 for set 656 | sola
# Processing record 1 for set 657 | hasaki
# Processing record 1 for set 658 | airai
# Processing record 1 for set 659 | bathsheba
# Processing record 1 for set 660 | dunhua
# Processing record 1 for set 661 | qianan
# Processing record 1 for set 662 | cherskiy
# Processing record 1 for set 663 | severomuysk
# Processing record 1 for set 664 | marin
# Processing record 1 for set 665 | yellowknife
# Processing record 1 for set 666 | hithadhoo
# Processing record 1 for set 667 | beringovskiy
# Processing record 1 for set 668 | severo-kurilsk
# Processing record 1 for set 669 | camana
# Processing record 1 for set 670 | charters towers
# City not found. Skipping...
# City not found. Skipping...
# Processing record 1 for set 671 | jos
# Processing record 1 for set 672 | chimore
# Processing record 1 for set 673 | iqaluit
# Processing record 1 for set 674 | bell ville
# Processing record 1 for set 675 | komsomolskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing record 1 for set 676 | kandrian
# Processing record 1 for set 677 | gobabis
# City not found. Skipping...
# Processing record 1 for set 678 | madang
# Processing record 1 for set 679 | batemans bay
# Processing record 1 for set 680 | arraial do cabo
# Processing record 1 for set 681 | hovd
# Processing record 1 for set 682 | mason city
# Processing record 1 for set 683 | petukhovo
# Processing record 1 for set 684 | lorengau
# Processing record 1 for set 685 | dikson
# Processing record 1 for set 686 | lichuan
# Processing record 1 for set 687 | katangli
# Processing record 1 for set 688 | plovdiv
# Processing record 1 for set 689 | qaanaaq
# Processing record 1 for set 690 | praia da vitoria
# Processing record 1 for set 691 | bubaque
# Processing record 1 for set 692 | ilulissat
# Processing record 1 for set 693 | asekeyevo
# Processing record 1 for set 694 | san patricio
# Processing record 1 for set 695 | castro
# City not found. Skipping...
# Processing record 1 for set 696 | inverness
# Processing record 1 for set 697 | laguna
# City not found. Skipping...
# Processing record 1 for set 698 | lompoc
# Processing record 1 for set 699 | sept-iles
# Processing record 1 for set 700 | puerto montt
# Processing record 1 for set 701 | bahia de caraquez
# Processing record 1 for set 702 | port hardy
# Processing record 1 for set 703 | bentiu
# Processing record 1 for set 704 | talnakh
# Processing record 1 for set 705 | trofors
# Processing record 1 for set 706 | jalu
# Processing record 1 for set 707 | mar del plata
# Processing record 1 for set 708 | ribeira grande
# Processing record 1 for set 709 | yingkou
# City not found. Skipping...
# Processing record 1 for set 710 | vila velha
# City not found. Skipping...
# Processing record 1 for set 711 | saint george
# Processing record 1 for set 712 | rawson
# Processing record 1 for set 713 | saint-louis
# Processing record 1 for set 714 | kijang
# Processing record 1 for set 715 | bacolod
# Processing record 1 for set 716 | atar
# Processing record 1 for set 717 | honningsvag
# Processing record 1 for set 718 | kaitangata
# City not found. Skipping...
# City not found. Skipping...
# Processing record 1 for set 719 | kysyl-syr
# Processing record 1 for set 720 | havelock
# City not found. Skipping...
# Processing record 1 for set 721 | upernavik
# Processing record 1 for set 722 | shimoda
# Processing record 1 for set 723 | ahipara
# Processing record 1 for set 724 | zheleznodorozhnyy
# Processing record 1 for set 725 | tukrah
# Processing record 1 for set 726 | trinidad
# Processing record 1 for set 727 | palpa
# Processing record 1 for set 728 | kirakira
# Processing record 1 for set 729 | buraydah
# Processing record 1 for set 730 | thompson
# Processing record 1 for set 731 | fairbanks
# Processing record 1 for set 732 | abu zabad
# Processing record 1 for set 733 | katsuura
# Processing record 1 for set 734 | ostrovnoy
# Processing record 1 for set 735 | imbituba
# Processing record 1 for set 736 | hobyo
# Processing record 1 for set 737 | meadow lake
# Processing record 1 for set 738 | lebu
# Processing record 1 for set 739 | lagoa
# Processing record 1 for set 740 | bambous virieux
# Processing record 1 for set 741 | saskylakh
# Processing record 1 for set 742 | turbat
# Processing record 1 for set 743 | ponta do sol
# Processing record 1 for set 744 | liepaja
# Processing record 1 for set 745 | great yarmouth
# Processing record 1 for set 746 | marsh harbour
# Processing record 1 for set 747 | nattam
# Processing record 1 for set 748 | victoria
# City not found. Skipping...
# Processing record 1 for set 749 | grindavik
# Processing record 1 for set 750 | souillac
# Processing record 1 for set 751 | kyra
# Processing record 1 for set 752 | halifax
# Processing record 1 for set 753 | aklavik
# Processing record 1 for set 754 | cabedelo
# Processing record 1 for set 755 | kyshtovka
# Processing record 1 for set 756 | calbuco
# Processing record 1 for set 757 | kondol
# Processing record 1 for set 758 | diego de almagro
# Processing record 1 for set 759 | paita
# Processing record 1 for set 760 | port shepstone
# Processing record 1 for set 761 | constancia
# Processing record 1 for set 762 | sinnamary
# Processing record 1 for set 763 | bredasdorp
# Processing record 1 for set 764 | anadyr
# Processing record 1 for set 765 | kungurtug
# Processing record 1 for set 766 | salinopolis
# Processing record 1 for set 767 | tuktoyaktuk
# Processing record 1 for set 768 | sinaloa
# Processing record 1 for set 769 | jutai
# Processing record 1 for set 770 | novoilinsk
# Processing record 1 for set 771 | benghazi
# Processing record 1 for set 772 | klyuchi
# Processing record 1 for set 773 | beira
# Processing record 1 for set 774 | nanortalik
# Processing record 1 for set 775 | chumikan
# Processing record 1 for set 776 | bonoua
# Processing record 1 for set 777 | rio grande
# Processing record 1 for set 778 | russell
# Processing record 1 for set 779 | cabo san lucas
# City not found. Skipping...
# Processing record 1 for set 780 | port macquarie
# Processing record 1 for set 781 | lazaro cardenas
# Processing record 1 for set 782 | mudigere
# Processing record 1 for set 783 | ulaangom
# Processing record 1 for set 784 | vardo
# Processing record 1 for set 785 | ewa beach
# City not found. Skipping...
# Processing record 1 for set 786 | wick
# Processing record 1 for set 787 | ayorou
# Processing record 1 for set 788 | cuiluan
# Processing record 1 for set 789 | maniitsoq
# Processing record 1 for set 790 | husum
# Processing record 1 for set 791 | houston
# Processing record 1 for set 792 | the valley
# Processing record 1 for set 793 | mount gambier
# Processing record 1 for set 794 | iguape
# Processing record 1 for set 795 | lentini
# Processing record 1 for set 796 | palenque
# Processing record 1 for set 797 | lavrentiya
# Processing record 1 for set 798 | azangaro
# Processing record 1 for set 799 | meulaboh
# Processing record 1 for set 800 | tautira
# Processing record 1 for set 801 | naryan-mar
# City not found. Skipping...
# Processing record 1 for set 802 | nouadhibou
# Processing record 1 for set 803 | iskateley
# Processing record 1 for set 804 | smithers
# Processing record 1 for set 805 | aksarka
# Processing record 1 for set 806 | ulladulla
# Processing record 1 for set 807 | husavik
# Processing record 1 for set 808 | ati
# Processing record 1 for set 809 | cheney
# Processing record 1 for set 810 | sakakah
# Processing record 1 for set 811 | nizwa
# City not found. Skipping...
# Processing record 1 for set 812 | shushtar
# Processing record 1 for set 813 | ajdabiya
# Processing record 1 for set 814 | leningradskiy
# Processing record 1 for set 815 | ozieri
# Processing record 1 for set 816 | ilebo
# Processing record 1 for set 817 | saint-pierre
# Processing record 1 for set 818 | tura
# Processing record 1 for set 819 | fort nelson
# Processing record 1 for set 820 | khilok
# Processing record 1 for set 821 | casino
# Processing record 1 for set 822 | lerwick
# Processing record 1 for set 823 | maragogi
# Processing record 1 for set 824 | sao joao da barra
# Processing record 1 for set 825 | namatanai
# Processing record 1 for set 826 | kinwat
# Processing record 1 for set 827 | usevya
# Processing record 1 for set 828 | faya
# Processing record 1 for set 829 | kristiansund
# Processing record 1 for set 830 | sitka
# Processing record 1 for set 831 | ust-koksa
# Processing record 1 for set 832 | sabha
# Processing record 1 for set 833 | luis correia
# Processing record 1 for set 834 | glens falls
# Processing record 1 for set 835 | lodja
# Processing record 1 for set 836 | vao
# Processing record 1 for set 837 | goderich
# Processing record 1 for set 838 | inirida
# City not found. Skipping...
# Processing record 1 for set 839 | san quintin
# Processing record 1 for set 840 | saint-augustin
# Processing record 1 for set 841 | zhigansk
# Processing record 1 for set 842 | chifeng
# City not found. Skipping...
# Processing record 1 for set 843 | harbour breton
# Processing record 1 for set 844 | redlands
# Processing record 1 for set 845 | doha
# Processing record 1 for set 846 | petropavlovsk-kamchatskiy
# Processing record 1 for set 847 | tunoshna
# Processing record 1 for set 848 | venice
# City not found. Skipping...
# Processing record 1 for set 849 | hamilton
# Processing record 1 for set 850 | verkhnevilyuysk
# Processing record 1 for set 851 | vestmannaeyjar
# Processing record 1 for set 852 | fortuna
# Processing record 1 for set 853 | belmonte
# Processing record 1 for set 854 | tuatapere
# Processing record 1 for set 855 | durmersheim
# Processing record 1 for set 856 | lancaster
# Processing record 1 for set 857 | cayenne
# Processing record 1 for set 858 | balikpapan
# Processing record 1 for set 859 | jurm
# Processing record 1 for set 860 | avera
# Processing record 1 for set 861 | baisha
# City not found. Skipping...
# Processing record 1 for set 862 | norman wells
# Processing record 1 for set 863 | dawei
# Processing record 1 for set 864 | jingdezhen
# City not found. Skipping...
# Processing record 1 for set 865 | lasa
# Processing record 1 for set 866 | sao filipe
# Processing record 1 for set 867 | college
# Processing record 1 for set 868 | deloraine
# Processing record 1 for set 869 | mitu
# Processing record 1 for set 870 | shafranovo
# Processing record 1 for set 871 | nara
# Processing record 1 for set 872 | huarmey
# Processing record 1 for set 873 | serdobsk
# City not found. Skipping...
# Processing record 1 for set 874 | mareeba
# Processing record 1 for set 875 | pisco
# Processing record 1 for set 876 | inhambane
# Processing record 1 for set 877 | tagusao
# City not found. Skipping...
# Processing record 1 for set 878 | coihaique
# Processing record 1 for set 879 | nhulunbuy
# Processing record 1 for set 880 | okhotsk
# Processing record 1 for set 881 | baijiantan
# Processing record 1 for set 882 | simiti
# Processing record 1 for set 883 | bilibino
# Processing record 1 for set 884 | zhangye
# Processing record 1 for set 885 | de-kastri
# Processing record 1 for set 886 | samarai
# Processing record 1 for set 887 | wiang sa
# Processing record 1 for set 888 | jaguariaiva
# Processing record 1 for set 889 | opuwo
# Processing record 1 for set 890 | clyde river
# Processing record 1 for set 891 | victoria point
# Processing record 1 for set 892 | san-pedro
# Processing record 1 for set 893 | methoni
# Processing record 1 for set 894 | changji
# Processing record 1 for set 895 | belaya gora
# Processing record 1 for set 896 | sydney
# Processing record 1 for set 897 | zetel
# Processing record 1 for set 898 | rosarito
# Processing record 1 for set 899 | maarianhamina
# Processing record 1 for set 900 | havre-saint-pierre
# Processing record 1 for set 901 | bali
# Processing record 1 for set 902 | filingue
# Processing record 1 for set 903 | oksfjord
# Processing record 1 for set 904 | canutama
# Processing record 1 for set 905 | pangnirtung
# Processing record 1 for set 906 | camacupa
# Processing record 1 for set 907 | maksatikha
# Processing record 1 for set 908 | matagami
# Processing record 1 for set 909 | pandan
# City not found. Skipping...
# Processing record 1 for set 910 | alanya
# Processing record 1 for set 911 | viransehir
# Processing record 1 for set 912 | hokitika
# Processing record 1 for set 913 | gorontalo
# Processing record 1 for set 914 | ixtapa
# Processing record 1 for set 915 | east london
# Processing record 1 for set 916 | dwarka
# Processing record 1 for set 917 | abilene
# Processing record 1 for set 918 | jinxiang
# Processing record 1 for set 919 | san andres
# Processing record 1 for set 920 | mtwara
# Processing record 1 for set 921 | mafinga
# Processing record 1 for set 922 | hauterive
# Processing record 1 for set 923 | okahandja
# City not found. Skipping...
# Processing record 1 for set 924 | mpika
# Processing record 1 for set 925 | constitucion
# Processing record 1 for set 926 | uppsala
# Processing record 1 for set 927 | deputatskiy
# Processing record 1 for set 928 | jinchang
# Processing record 1 for set 929 | north bend
# Processing record 1 for set 930 | alyangula
# Processing record 1 for set 931 | iracoubo
# Processing record 1 for set 932 | hualmay
# Processing record 1 for set 933 | redcliffe
# Processing record 1 for set 934 | krasnoselkup
# City not found. Skipping...
# Processing record 1 for set 935 | marienburg
# Processing record 1 for set 936 | richards bay
# Processing record 1 for set 937 | pakxe
# City not found. Skipping...
# Processing record 1 for set 938 | eureka
# Processing record 1 for set 939 | otukpo
# Processing record 1 for set 940 | narsaq
# Processing record 1 for set 941 | colac
# Processing record 1 for set 942 | nanyamba
# Processing record 1 for set 943 | badou
# Processing record 1 for set 944 | targu bujor
# Processing record 1 for set 945 | forbes
# Processing record 1 for set 946 | hofn
# Processing record 1 for set 947 | roald
# Processing record 1 for set 948 | roma
# Processing record 1 for set 949 | eagle pass
# Processing record 1 for set 950 | stornoway
# Processing record 1 for set 951 | ikom
# Processing record 1 for set 952 | ust-maya
# City not found. Skipping...
# Processing record 1 for set 953 | satara
# Processing record 1 for set 954 | maningrida
# Processing record 1 for set 955 | nouakchott
# Processing record 1 for set 956 | ayan
# Processing record 1 for set 957 | baruun-urt
# Processing record 1 for set 958 | yulara
# Processing record 1 for set 959 | kamaishi
# Processing record 1 for set 960 | pachmarhi
# Processing record 1 for set 961 | tamalin
# Processing record 1 for set 962 | san policarpo
# Processing record 1 for set 963 | goure
# Processing record 1 for set 964 | eganville
# Processing record 1 for set 965 | seddon
# Processing record 1 for set 966 | listvyanskiy
# Processing record 1 for set 967 | grand gaube
# Processing record 1 for set 968 | marovoay
# Processing record 1 for set 969 | port lincoln
# Processing record 1 for set 970 | gualaquiza
# Processing record 1 for set 971 | olinda
# Processing record 1 for set 972 | egvekinot
# Processing record 1 for set 973 | cherkasskoye
# Processing record 1 for set 974 | esperance
# Processing record 1 for set 975 | tawang
# Processing record 1 for set 976 | nevesinje
# Processing record 1 for set 977 | souris
# Processing record 1 for set 978 | toamasina
# Processing record 1 for set 979 | noumea
# Processing record 1 for set 980 | riyadh
# Processing record 1 for set 981 | vilanova del cami
# Processing record 1 for set 982 | sioux city
# Processing record 1 for set 983 | antalaha
# Processing record 1 for set 984 | mezen
# Processing record 1 for set 985 | sorong
# Processing record 1 for set 986 | hay river
# Processing record 1 for set 987 | swan hill
# Processing record 1 for set 988 | freeport
# City not found. Skipping...
# Processing record 1 for set 989 | urengoy
# Processing record 1 for set 990 | ganzhou
# Processing record 1 for set 991 | itarema
# Processing record 1 for set 992 | faanui
# Processing record 1 for set 993 | japura
# Processing record 1 for set 994 | cockburn town
# Processing record 1 for set 995 | turukhansk
# Processing record 1 for set 996 | champerico
# Processing record 1 for set 997 | dickinson
# Processing record 1 for set 998 | vuktyl
# Processing record 1 for set 999 | tyukalinsk
# City not found. Skipping...
# Processing record 1 for set 1000 | snezhnogorsk
# Processing record 1 for set 1001 | cairns
# Processing record 1 for set 1002 | puerto del rosario
# Processing record 1 for set 1003 | longyan
# Processing record 1 for set 1004 | kaputa
# Processing record 1 for set 1005 | sao miguel do araguaia
# Processing record 1 for set 1006 | phan thiet
# Processing record 1 for set 1007 | gryazi
# Processing record 1 for set 1008 | kupang
# Processing record 1 for set 1009 | trincomalee
# Processing record 1 for set 1010 | karaton
# Processing record 1 for set 1011 | mehamn
# Processing record 1 for set 1012 | kemi
# Processing record 1 for set 1013 | jimo
# Processing record 1 for set 1014 | maumere
# Processing record 1 for set 1015 | surt
# Processing record 1 for set 1016 | kozhva
# Processing record 1 for set 1017 | bulgan
# Processing record 1 for set 1018 | hambantota
# Processing record 1 for set 1019 | port hawkesbury
# Processing record 1 for set 1020 | lotoshino
# Processing record 1 for set 1021 | mabaruma
# Processing record 1 for set 1022 | buala
# Processing record 1 for set 1023 | soyo
# Processing record 1 for set 1024 | hayden
# Processing record 1 for set 1025 | saint-joseph
# Processing record 1 for set 1026 | imeni poliny osipenko
# Processing record 1 for set 1027 | dalbandin
# Processing record 1 for set 1028 | coolum beach
# Processing record 1 for set 1029 | pag
# Processing record 1 for set 1030 | obidos
# Processing record 1 for set 1031 | berlevag
# Processing record 1 for set 1032 | nantucket
# Processing record 1 for set 1033 | adre
# Processing record 1 for set 1034 | labuhan
# Processing record 1 for set 1035 | broken hill
# Processing record 1 for set 1036 | gawler
# Processing record 1 for set 1037 | aranda de duero
# Processing record 1 for set 1038 | tamandare
# Processing record 1 for set 1039 | paso de carrasco
# City not found. Skipping...
# Processing record 1 for set 1040 | pacific grove
# Processing record 1 for set 1041 | mirabad
# Processing record 1 for set 1042 | srednekolymsk
# Processing record 1 for set 1043 | aripuana
# City not found. Skipping...
# Processing record 1 for set 1044 | santa catarina de tepehuanes
# Processing record 1 for set 1045 | gornopravdinsk
# Processing record 1 for set 1046 | zhanaozen
# Processing record 1 for set 1047 | tulagi
# Processing record 1 for set 1048 | verkhoyansk
# Processing record 1 for set 1049 | sawtell
# Processing record 1 for set 1050 | quang ngai
# Processing record 1 for set 1051 | poum
# Processing record 1 for set 1052 | sao raimundo das mangabeiras
# Processing record 1 for set 1053 | biak
# Processing record 1 for set 1054 | denia
# Processing record 1 for set 1055 | bima
# Processing record 1 for set 1056 | tabou
# Processing record 1 for set 1057 | codrington
# Processing record 1 for set 1058 | marsa matruh
# City not found. Skipping...
# Processing record 1 for set 1059 | dauriya
# Processing record 1 for set 1060 | nelson bay
# Processing record 1 for set 1061 | sumbawanga
# Processing record 1 for set 1062 | tiznit
# Processing record 1 for set 1063 | bocaiuva
# Processing record 1 for set 1064 | aitape
# Processing record 1 for set 1065 | rio gallegos
# Processing record 1 for set 1066 | rio verde de mato grosso
# Processing record 1 for set 1067 | tromso
# Processing record 1 for set 1068 | araouane
# Processing record 1 for set 1069 | bunbury
# Processing record 1 for set 1070 | kilindoni
# Processing record 1 for set 1071 | kataysk
# Processing record 1 for set 1072 | tiksi
# Processing record 1 for set 1073 | kyzyl-suu
# Processing record 1 for set 1074 | tumarbong
# Processing record 1 for set 1075 | dzaoudzi
# Processing record 1 for set 1076 | kaithal
# Processing record 1 for set 1077 | road town
# Processing record 1 for set 1078 | qaqortoq
# Processing record 1 for set 1079 | dunedin
# City not found. Skipping...
# Processing record 1 for set 1080 | quatre cocos
# Processing record 1 for set 1081 | kununurra
# Processing record 1 for set 1082 | misratah
# Processing record 1 for set 1083 | xiazhen
# Processing record 1 for set 1084 | geraldton
# Processing record 1 for set 1085 | along
# Processing record 1 for set 1086 | hue
# Processing record 1 for set 1087 | kanakapura
# Processing record 1 for set 1088 | cayeli
# Processing record 1 for set 1089 | svetlyy
# City not found. Skipping...
# Processing record 1 for set 1090 | loksa
# City not found. Skipping...
# Processing record 1 for set 1091 | rangpur
# Processing record 1 for set 1092 | yaan
# Processing record 1 for set 1093 | megion
# Processing record 1 for set 1094 | whitianga
# Processing record 1 for set 1095 | malanje
# Processing record 1 for set 1096 | silvan
# Processing record 1 for set 1097 | umba
# Processing record 1 for set 1098 | wonthaggi
# Processing record 1 for set 1099 | alice springs
# Processing record 1 for set 1100 | shagonar
# Processing record 1 for set 1101 | olafsvik
# Processing record 1 for set 1102 | bandarbeyla
# ----------
# Data retrieval complete:)
# -----------

# %% [markdown]
# ## Dataframe creation and cleaning

# %%
# create dictionary 
info_df = pd.DataFrame({
    'City': citi,
    'Country':country,
    'Latitude':latitudes,
    'Longitude':longitudes,
    'Humidity':humidity,
    'Windspeed':windspeed,
    'Cloudiness':cloudiness,
    'Temperatures':temperatures,
    'Date':date
})
info_df.head()

# %%
# get summary statistics
info_df.describe()
# Out:
#          Latitude   Longitude   Humidity   Windspeed  Cloudiness  \
# count  551.000000  551.000000  551.00000  551.000000  551.000000
# mean    19.566400   25.312663   70.85118    8.266842   55.765880
# std     34.321431   91.049668   20.24737    5.915410   41.349174
# min    -54.800000 -179.166700    1.00000    0.090000    0.000000
# 25%     -9.698600  -54.152900   63.00000    3.670000   10.000000
# 50%     24.223100   29.086400   75.00000    6.910000   69.000000
# 75%     50.216750  108.757150   85.00000   11.500000  100.000000
# max     78.218600  179.316700  100.00000   38.300000  100.000000
#
#        Temperatures          Date
# count    551.000000  5.510000e+02
# mean      66.006806  1.655170e+09
# std       14.225199  1.074694e+02
# min       25.480000  1.655169e+09
# 25%       55.175000  1.655170e+09
# 50%       67.440000  1.655170e+09
# 75%       77.235000  1.655170e+09
# max      100.270000  1.655170e+09

# %%
# remove cities with humidity >100
# info_df['Humidity'].value_counts()
humidity_check = info_df.sort_values('Humidity', ascending=False)
print('No values >100 in humidity, thus plot!')
humidity_check.head()
# Out:
# No values >100 in humidity, thus plot!
#              City Country  Latitude  Longitude  Humidity  Windspeed  \
# 148  puerto montt      CL  -41.4698   -72.9447       100      10.36
# 65       sandwick      GB   60.0000    -1.2500       100      12.66
# 136       plovdiv      BG   42.1500    24.7500       100       2.30
# 306    balikpapan      ID   -1.2675   116.8289       100       2.30
# 295      tunoshna      RU   57.5459    40.1254       100       4.47
#
#      Cloudiness  Temperatures        Date
# 148         100         47.23  1655169636
# 65           40         49.82  1655169613
# 136           0         64.47  1655169633
# 306          40         77.99  1655169682
# 295          77         55.38  1655169679

# %%
info_df.dtypes
# Out:
# City             object
# Country          object
# Latitude        float64
# Longitude       float64
# Humidity          int64
# Windspeed       float64
# Cloudiness        int64
# Temperatures    float64
# Date              int64
# dtype: object

# %% [markdown]
# ## Plotting scatterplots

# %%
# create temp vs lat scatter
y1= info_df['Temperatures']
x1= info_df['Latitude']
plt.scatter(x1,y1, marker='o',edgecolors='red')
plt.grid()
plt.xlabel('latitude')
plt.ylabel('temperature (F)')
plt.title('Latitude vs Temp(F)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# create humidity vs lat scatter
x2= info_df['Latitude']
y2= info_df['Humidity']
plt.scatter(x2,y2, marker='x')
plt.grid()
plt.xlabel('latitude')
plt.ylabel('humidity (%)')
plt.title('Latitude vs Humidity(%)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# create cloudiness vs lat scatter
x3= info_df['Latitude']
y3= info_df['Cloudiness']
plt.scatter(x3,y3, marker='*')
plt.grid()
plt.xlabel('latitude')
plt.ylabel('cloudiness')
plt.title('Latitude vs Cloudiness')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# create humidity vs lat scatter
x4= info_df['Latitude']
y4= info_df['Windspeed']
plt.scatter(x4,y4, marker='x')
plt.grid()
plt.xlabel('latitude')
plt.ylabel('windspeed (mph)')
plt.title('Latitude vs Windspeed(mph)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ### Northern Hemisphere

# %%
# using original dataframe create a northern hemisphere dataframe 
# in this case latitude will be > 0
# equator = 0
northern_hem_df = info_df[info_df['Latitude']>0]
northern_hem_df.head()
# Out:
#                     City Country  Latitude  Longitude  Humidity  Windspeed  \
# 0                kamenka      RU   51.3223    42.7678        63       8.41
# 4   vila franca do campo      PT   37.7167   -25.4333        86       7.72
# 5             georgetown      MY    5.4112   100.3354        87       3.44
# 11                martil      MA   35.6166    -5.2752        78       2.30
# 12             high rock      BS   26.6208   -78.2833        76      11.86
#
#     Cloudiness  Temperatures        Date
# 0          100         61.36  1655169926
# 4           22         64.20  1655169927
# 5           20         82.45  1655169689
# 11         100         71.56  1655169599
# 12           5         82.42  1655169599

# %%
# linregress temp vs lat on scatter
yn1= northern_hem_df['Temperatures']
xn1= northern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xn1, yn1)
regress_values = xn1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xn1,yn1, marker='^')
plt.plot(xn1,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('temperature (F)')
plt.title('Latitude vs Temp(F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5836529177864292

# %%
# linregress humidity vs lat on scatter
yn2= northern_hem_df['Humidity']
xn2= northern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xn2, yn2)
regress_values = xn1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xn2,yn2, marker='x')
plt.plot(xn2,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('Humidity (%)')
plt.title('Latitude vs Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00039524185912452717

# %%
# linregress cloudiness vs lat on scatter
yn3= northern_hem_df['Cloudiness']
xn3= northern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xn3, yn3)
regress_values = xn3 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xn3,yn3, marker='*')
plt.plot(xn3,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('Cloudiness(%)')
plt.title('Latitude vs Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.01184830081125471

# %%
# linregress windspeed vs lat on scatter
yn4= northern_hem_df['Windspeed']
xn4= northern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xn4, yn4)
regress_values = xn4 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xn4,yn4, marker='o')
plt.plot(xn4,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('Windspeed (mph)')
plt.title('Latitude vs Windspeed(mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0011961826485536633

# %% [markdown]
# ### Southern Hemisphere

# %%
# using original dataframe create a southern hemisphere dataframe 
# in this case latitude will be < 0
# equator = 0
southern_hem_df = info_df[info_df['Latitude']<0]
southern_hem_df.head()
# Out:
#            City Country  Latitude  Longitude  Humidity  Windspeed  Cloudiness  \
# 1     busselton      AU  -33.6500   115.3333        68       8.21          13
# 2  kruisfontein      ZA  -34.0033    24.7314        50       3.69         100
# 3   port alfred      ZA  -33.5906    26.8910        50       7.07         100
# 6      saldanha      ZA  -33.0117    17.9442        78      19.44          14
# 7     mahebourg      MU  -20.4081    57.7000        68      17.27          40
#
#    Temperatures        Date
# 1         61.27  1655169926
# 2         59.20  1655169927
# 3         69.87  1655169927
# 6         57.43  1655169928
# 7         71.89  1655169708

# %%
# linregress temp vs lat on scatter
ys1= southern_hem_df['Temperatures']
xs1= southern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xs1, ys1)
regress_values = xs1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xs1,ys1, marker='o')
plt.plot(xs1,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('temperature (F)')
plt.title('Latitude vs Temp(F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5611090626048459

# %%
# linregress temp vs lat on scatter
ys2= southern_hem_df['Humidity']
xs2= southern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xs2, ys2)
regress_values = xs2 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xs2,ys2, marker='o')
plt.plot(xs2,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('Humidity (%)')
plt.title('Latitude vs Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.012928731328857702

# %%
# linregress temp vs lat on scatter
ys3= southern_hem_df['Cloudiness']
xs3= southern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xs3, ys3)
regress_values = xs3 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xs3,ys3, marker='o')
plt.plot(xs3,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Latitude vs Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.02189985812101162

# %%
# linregress windspeed vs lat on scatter
ys4= southern_hem_df['Windspeed']
xs4= southern_hem_df['Latitude']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xs4, ys4)
regress_values = xs4 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xs4,ys4, marker='o')
plt.plot(xs4,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid()
plt.xlabel('latitude')
plt.ylabel('Windspeed (mph)')
plt.title('Latitude vs Windspeed(mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.10757620681982745
